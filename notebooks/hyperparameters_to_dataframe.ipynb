# %% [markdown]
# # Create DataFrame for automated training of networks
# Below, we define a dataframe in which training hyperparameters of interest for experimentation and more mundane parameters like flags for saving models are listed. Work in progress.

# %%
# %load_ext autoreload
# %autoreload 2
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys, os, time
# path to current project
sys.path.append("/mnt/hd_internal/hh/projects_DS/numeric_precision/")
# path into which to save dataframe
df_dir = "../models"

# %% [markdown]
# Batches of images

# %%
# total number of model runs
num_runs = 100

# model type ("convnet_01", "VGG16" or "InceptionV3")
#parameters_train = pd.DataFrame(np.tile(np.array(["convnet_01"]), [num_runs, 1])  , columns=["model_type"])
#parameters_train = pd.DataFrame(np.tile(np.array(["VGG16"]), [num_runs, 1])  , columns=["model_type"])
parameters_train = pd.DataFrame(np.tile(np.array(["InceptionV3"]), [num_runs, 1])  , columns=["model_type"])

# model weights
parameters_train["model_weights"] = np.tile(np.array(["imagenet"]), [num_runs, 1])
#parameters_train["model_weights"] = np.tile(np.array(["None"]), [num_runs, 1])


# name of model 
parameters_train["model_name"] = np.tile(np.array(["undefined"]), [num_runs, 1])

# batch size 
parameters_train["batch_size"] = np.ones((num_runs, 1), dtype=int)*16

# number of epochs
parameters_train["num_epochs"] = np.ones((num_runs, 1), dtype=int)*50

# perform image augmentation on training set?
parameters_train["do_img_augment"] = np.ones((num_runs, 1), dtype=bool)

# optimizer
parameters_train["optimizer"] = np.tile(np.array(["RMSprop"]), [num_runs, 1])

# (initial) learning rate
parameters_train["learn_rate"] = np.ones((num_runs, 1))*0.001

# name of learning rate schedule
parameters_train["lr_schedule"] = np.tile(np.array(["step_decay"]), [num_runs, 1])

# this parameter decides which of the two combinations of last layer activation 
# and implementation of loss function shall be used for training; set to either
# "raw" or "sigmoid"
parameters_train["loss_basis"] = np.tile(np.array([["sigmoid"], ["raw"]]), [num_runs // 2, 1])

# shall tensorboard logging be performed?
parameters_train["do_tensorboard"] = np.ones((num_runs, 1), dtype=bool)

# how to save model, if at all? "ModelCheckpoint" or "None"
parameters_train["save_model"] = np.tile(np.array(["None"]), [num_runs, 1])
#parameters_train.loc[:10, "save_model"] = "ModelCheckpoint"

# save dataframe to file
parameters_train.to_csv(os.path.join(df_dir, "train_params.csv"), index=True)

# peek at its contents
parameters_train.head(20)
# Out:
#      model_type model_weights model_name  batch_size  num_epochs  \
# 0   InceptionV3      imagenet  undefined          16          50
# 1   InceptionV3      imagenet  undefined          16          50
# 2   InceptionV3      imagenet  undefined          16          50
# 3   InceptionV3      imagenet  undefined          16          50
# 4   InceptionV3      imagenet  undefined          16          50
# 5   InceptionV3      imagenet  undefined          16          50
# 6   InceptionV3      imagenet  undefined          16          50
# 7   InceptionV3      imagenet  undefined          16          50
# 8   InceptionV3      imagenet  undefined          16          50
# 9   InceptionV3      imagenet  undefined          16          50
# 10  InceptionV3      imagenet  undefined          16          50
# 11  InceptionV3      imagenet  undefined          16          50
# 12  InceptionV3      imagenet  undefined          16          50
# 13  InceptionV3      imagenet  undefined          16          50
# 14  InceptionV3      imagenet  undefined          16          50
# 15  InceptionV3      imagenet  undefined          16          50
# 16  InceptionV3      imagenet  undefined          16          50
# 17  InceptionV3      imagenet  undefined          16          50
# 18  InceptionV3      imagenet  undefined          16          50
# 19  InceptionV3      imagenet  undefined          16          50
#
#     do_img_augment optimizer  learn_rate lr_schedule loss_basis  \
# 0             True   RMSprop       0.001  step_decay    sigmoid
# 1             True   RMSprop       0.001  step_decay        raw
# 2             True   RMSprop       0.001  step_decay    sigmoid
# 3             True   RMSprop       0.001  step_decay        raw
# 4             True   RMSprop       0.001  step_decay    sigmoid
# 5             True   RMSprop       0.001  step_decay        raw
# 6             True   RMSprop       0.001  step_decay    sigmoid
# 7             True   RMSprop       0.001  step_decay        raw
# 8             True   RMSprop       0.001  step_decay    sigmoid
# 9             True   RMSprop       0.001  step_decay        raw
# 10            True   RMSprop       0.001  step_decay    sigmoid
# 11            True   RMSprop       0.001  step_decay        raw
# 12            True   RMSprop       0.001  step_decay    sigmoid
# 13            True   RMSprop       0.001  step_decay        raw
# 14            True   RMSprop       0.001  step_decay    sigmoid
# 15            True   RMSprop       0.001  step_decay        raw
# 16            True   RMSprop       0.001  step_decay    sigmoid
# 17            True   RMSprop       0.001  step_decay        raw
# 18            True   RMSprop       0.001  step_decay    sigmoid
# 19            True   RMSprop       0.001  step_decay        raw
#
#     do_tensorboard save_model
# 0             True       None
# 1             True       None
# 2             True       None
# 3             True       None
# 4             True       None
# 5             True       None
# 6             True       None
# 7             True       None
# 8             True       None
# 9             True       None
# 10            True       None
# 11            True       None
# 12            True       None
# 13            True       None
# 14            True       None
# 15            True       None
# 16            True       None
# 17            True       None
# 18            True       None
# 19            True       None
